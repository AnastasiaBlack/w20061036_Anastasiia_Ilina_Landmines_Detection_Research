# %% [markdown]
# <a href="https://colab.research.google.com/github/AnastasiaBlack/w20061036_Anastasiia_Ilina_Landmines_Detection_Research/blob/main/colabFiles/Two_Bounding_Boxes(GroundTruth_and_Detected).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This code was used to create images that contain both the detected object rectangle with the ground truth rectangle drawn on the same image, but both rectangles have different colours.

# %%
# convert normalized boxes to coordinates

def convert_normalized_to_coordinates(normalized_bbox):
  # Unpack the normalized bounding box
  x_center, y_center, width, height = normalized_bbox
  # Assuming image width and height
  image_width = 336
  image_height = 256
  # Convert normalized coordinates to image coordinates
  x_min = int((x_center - width / 2) * image_width)
  y_min = int((y_center - height / 2) * image_height)
  x_max = int((x_center + width / 2) * image_width)
  y_max = int((y_center + height / 2) * image_height)

  return x_min, y_min, x_max, y_max

# %%
def load_boxes_from_txt(txt_path, is_normalized=True, images_with_no_detection=[], is_detection=False):
    try:
      with open(txt_path, 'r') as f:
        lines = f.readlines()
    except FileNotFoundError:
      print(f"The file {txt_path} does not exist.")
      if is_detection:
        images_with_no_detection.append(txt_path)
      return []

    boxes = []
    for line in lines:
        parts = line.strip().split()
        if len(parts) == 5:
          confidence = float(parts[1])
          x_min, y_min, x_max, y_max = map(float, parts[1:])
        elif len(parts) == 4:
        # Assuming class_id is 0 if not provided
          x_min, y_min, x_max, y_max = map(float, parts[0:])
        elif len(parts) == 6:
          confidence = float(parts[1])
          x_min, y_min, x_max, y_max = map(float, parts[2:])

        if is_normalized:
            # Convert normalized coordinates to absolute coordinates
            x_min, y_min, x_max, y_max=convert_normalized_to_coordinates((x_min, y_min, x_max, y_max))

        if is_detection:
          boxes.append((float(confidence), int(x_min), int(y_min), int(x_max), int(y_max)))
        else:
          boxes.append((int(x_min), int(y_min), int(x_max), int(y_max)))

    return boxes

# %% [markdown]
#  The code is based on OpenCv library (https://docs.opencv.org/3.4/dc/da5/tutorial_py_drawing_functions.html)

# %%
import cv2
import os
from PIL import Image
from xml.etree import ElementTree as ET

def draw_boxes(image_path, ground_truth_boxes, detected_boxes, output_path):
    # Read the image
    image = cv2.imread(image_path)

    # Draw ground truth bounding boxes in red
    for box in ground_truth_boxes:
        x_min, y_min, x_max, y_max = box
        # cv2.rectangle(image, (xmin, ymin), (xmax, ymax), (255, 0, 0), 2)  # Blue color
        cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 0, 255), 2)


    # Draw detected bounding boxes in green
    for box in detected_boxes:
        confidence, x_min, y_min, x_max, y_max = box
        print("Detected boxes: ", x_min, y_min, x_max, y_max)
        cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
        # Prepare the label text
        label = f"'landmines' {confidence:.2f}%"  # Example format: "cat 82.00%"
        # Calculate the position to place the label above the bounding box
        # label_position = (x_min, y_min - 5)
        image_width=image.shape[1]
        image_height = image.shape[0]

        # Get the size of the label text
        (label_width, label_height), baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2)

        # Calculate the label position
        label_x = max(min(x_min, image_width - label_width), 0)
        label_y = max(min(y_min - 5, image_height - label_height), 0)
        label_position = (label_x, label_y)
        # Draw black border and green text
        cv2.putText(image, label, label_position, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
        cv2.putText(image, label, label_position, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1, cv2.LINE_AA)


    # Save or display the image
    cv2.imwrite(output_path, image)

# %%
# Folder paths
import os
output_folder = "/content/result_boundingbox_images"
# Create the directory if it doesn't exist
os.makedirs(output_folder, exist_ok=True)


image_folder = "/content/drive/MyDrive/University/Research_Module/dataset/Yolov8_v3_dataset/Landmines detection dataset.v3i.yolov8/test/images"
ground_truth_folder = "/content/drive/MyDrive/University/Research_Module/dataset/Yolov8_v3_dataset/Landmines detection dataset.v3i.yolov8/test/labels"  # Change to your ground truth folder path
detected_folder = "/content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO"

images_with_no_detection=[]

# Iterate over images in the image folder
for image_name in os.listdir(image_folder):
    image_path = os.path.join(image_folder, image_name)

    # Load ground truth and detected boxes
    ground_truth_path = os.path.join(ground_truth_folder, os.path.splitext(image_name)[0] + ".txt")
    detected_path = os.path.join(detected_folder, os.path.splitext(image_name)[0] + ".txt")

    ground_truth_boxes = load_boxes_from_txt(ground_truth_path, True)
    print("Initial ground_truth_boxes: ",ground_truth_boxes);
    detected_boxes = load_boxes_from_txt(detected_path, False, images_with_no_detection, True)
    print("Initial detected boxes: ",detected_boxes);

    # Draw and save the image with bounding boxes
    output_path = os.path.join(output_folder, os.path.splitext(image_name)[0] + "_result.jpg")
    draw_boxes(image_path, ground_truth_boxes, detected_boxes, output_path)
print("Images without detected objects: ", images_with_no_detection) #they do not include the cases when there are multiple objects and 1 was missed
# Out:
# Initial ground_truth_boxes:  [(81, 76, 155, 134)]
# Initial detected boxes:  [(88.0, 83, 80, 149, 133)]
# Detected boxes:  83 80 149 133
# Initial ground_truth_boxes:  [(115, 71, 155, 102)]
# Initial detected boxes:  [(82.0, 111, 72, 151, 103)]
# Detected boxes:  111 72 151 103
# Initial ground_truth_boxes:  [(105, 85, 198, 154)]
# Initial detected boxes:  [(87.0, 107, 82, 198, 151)]
# Detected boxes:  107 82 198 151
# Initial ground_truth_boxes:  [(137, 100, 178, 139)]
# Initial detected boxes:  [(62.0, 144, 110, 170, 135)]
# Detected boxes:  144 110 170 135
# Initial ground_truth_boxes:  [(113, 111, 137, 131)]
# Initial detected boxes:  [(70.0, 112, 110, 138, 133)]
# Detected boxes:  112 110 138 133
# Initial ground_truth_boxes:  [(115, 126, 146, 150)]
# Initial detected boxes:  [(75.0, 116, 122, 153, 151)]
# Detected boxes:  116 122 153 151
# Initial ground_truth_boxes:  [(113, 137, 143, 165)]
# Initial detected boxes:  [(89.0, 110, 134, 144, 168)]
# Detected boxes:  110 134 144 168
# Initial ground_truth_boxes:  [(105, 91, 199, 166)]
# Initial detected boxes:  [(88.0, 106, 90, 198, 166)]
# Detected boxes:  106 90 198 166
# Initial ground_truth_boxes:  [(151, 130, 172, 153)]
# Initial detected boxes:  [(82.0, 150, 130, 174, 154)]
# Detected boxes:  150 130 174 154
# Initial ground_truth_boxes:  [(129, 147, 143, 160), (135, 0, 154, 13)]
# Initial detected boxes:  [(46.0, 132, 149, 144, 160)]
# Detected boxes:  132 149 144 160
# Initial ground_truth_boxes:  [(112, 122, 124, 137)]
# Initial detected boxes:  [(87.0, 111, 123, 124, 137)]
# Detected boxes:  111 123 124 137
# Initial ground_truth_boxes:  [(136, 55, 273, 167)]
# Initial detected boxes:  [(86.0, 139, 58, 271, 170)]
# Detected boxes:  139 58 271 170
# Initial ground_truth_boxes:  [(144, 116, 172, 140)]
# Initial detected boxes:  [(77.0, 141, 110, 171, 140)]
# Detected boxes:  141 110 171 140
# Initial ground_truth_boxes:  [(285, 103, 300, 122)]
# Initial detected boxes:  [(37.0, 286, 106, 299, 122)]
# Detected boxes:  286 106 299 122
# Initial ground_truth_boxes:  [(134, 106, 202, 186)]
# Initial detected boxes:  [(86.0, 135, 106, 199, 183)]
# Detected boxes:  135 106 199 183
# Initial ground_truth_boxes:  [(108, 115, 182, 176)]
# Initial detected boxes:  [(76.0, 119, 123, 185, 181)]
# Detected boxes:  119 123 185 181
# Initial ground_truth_boxes:  [(125, 92, 149, 115), (275, 127, 287, 140)]
# Initial detected boxes:  [(60.0, 275, 129, 286, 141)]
# Detected boxes:  275 129 286 141
# Initial ground_truth_boxes:  []
# The file /content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/355_Zone_6__free_zone__4-0m_TemperatureInCenter__32-C_jpg.rf.5c243c643decb8828712740624fce6b4.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(135, 30, 234, 168)]
# Initial detected boxes:  [(90.0, 133, 30, 235, 167)]
# Detected boxes:  133 30 235 167
# Initial ground_truth_boxes:  [(146, 126, 164, 141)]
# Initial detected boxes:  [(68.0, 146, 125, 165, 142)]
# Detected boxes:  146 125 165 142
# Initial ground_truth_boxes:  [(113, 131, 144, 162)]
# Initial detected boxes:  [(59.0, 116, 138, 144, 164)]
# Detected boxes:  116 138 144 164
# Initial ground_truth_boxes:  [(103, 95, 198, 170)]
# Initial detected boxes:  [(85.0, 108, 100, 198, 170)]
# Detected boxes:  108 100 198 170
# Initial ground_truth_boxes:  [(128, 83, 171, 110)]
# Initial detected boxes:  [(84.0, 127, 80, 181, 120)]
# Detected boxes:  127 80 181 120
# Initial ground_truth_boxes:  [(66, 0, 241, 136)]
# Initial detected boxes:  [(83.0, 69, 0, 252, 138)]
# Detected boxes:  69 0 252 138
# Initial ground_truth_boxes:  [(128, 30, 190, 108)]
# Initial detected boxes:  [(85.0, 123, 33, 193, 107)]
# Detected boxes:  123 33 193 107
# Initial ground_truth_boxes:  [(208, 80, 230, 99)]
# Initial detected boxes:  [(77.0, 209, 79, 233, 101)]
# Detected boxes:  209 79 233 101
# Initial ground_truth_boxes:  []
# The file /content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/75_Zone_6__free_zone__1-7m_TemperatureInCenter__30-C_jpg.rf.10b33677800c257b702e5a2b4c294e20.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(115, 137, 129, 150)]
# Initial detected boxes:  [(44.0, 115, 137, 128, 149)]
# Detected boxes:  115 137 128 149
# Initial ground_truth_boxes:  [(135, 91, 157, 114)]
# Initial detected boxes:  [(80.0, 132, 121, 177, 155)]
# Detected boxes:  132 121 177 155
# Initial ground_truth_boxes:  [(119, 21, 201, 89)]
# Initial detected boxes:  [(73.0, 119, 16, 203, 90)]
# Detected boxes:  119 16 203 90
# Initial ground_truth_boxes:  [(140, 137, 162, 156)]
# Initial detected boxes:  [(76.0, 138, 134, 164, 157)]
# Detected boxes:  138 134 164 157
# Initial ground_truth_boxes:  [(181, 129, 201, 147)]
# Initial detected boxes:  [(32.0, 173, 128, 200, 151)]
# Detected boxes:  173 128 200 151
# Initial ground_truth_boxes:  [(86, 1, 279, 199)]
# Initial detected boxes:  [(90.0, 100, 5, 262, 200)]
# Detected boxes:  100 5 262 200
# Initial ground_truth_boxes:  [(146, 104, 158, 116)]
# Initial detected boxes:  [(81.0, 145, 103, 159, 117)]
# Detected boxes:  145 103 159 117
# Initial ground_truth_boxes:  [(126, 96, 140, 110)]
# Initial detected boxes:  [(78.0, 125, 96, 141, 112)]
# Detected boxes:  125 96 141 112
# Initial ground_truth_boxes:  [(122, 65, 161, 100)]
# Initial detected boxes:  [(87.0, 122, 66, 159, 103)]
# Detected boxes:  122 66 159 103
# Initial ground_truth_boxes:  [(156, 151, 169, 163)]
# Initial detected boxes:  [(76.0, 156, 151, 170, 164)]
# Detected boxes:  156 151 170 164
# Initial ground_truth_boxes:  [(105, 130, 133, 157)]
# Initial detected boxes:  [(90.0, 103, 127, 136, 160)]
# Detected boxes:  103 127 136 160
# Initial ground_truth_boxes:  [(141, 106, 174, 138)]
# Initial detected boxes:  [(89.0, 140, 105, 174, 139)]
# Detected boxes:  140 105 174 139
# Initial ground_truth_boxes:  [(108, 109, 122, 122)]
# Initial detected boxes:  [(78.0, 106, 110, 122, 124)]
# Detected boxes:  106 110 122 124
# Initial ground_truth_boxes:  [(167, 38, 255, 167)]
# Initial detected boxes:  [(90.0, 165, 36, 255, 163)]
# Detected boxes:  165 36 255 163
# Initial ground_truth_boxes:  []
# The file /content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/208_Zone_6__free_zone__2-4m_TemperatureInCenter__30-C_jpg.rf.107304a301815c828391449a671ddba5.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(132, 134, 161, 157)]
# Initial detected boxes:  [(70.0, 135, 132, 161, 156)]
# Detected boxes:  135 132 161 156
# Initial ground_truth_boxes:  [(99, 144, 124, 169)]
# Initial detected boxes:  [(82.0, 100, 143, 122, 166)]
# Detected boxes:  100 143 122 166
# Initial ground_truth_boxes:  [(147, 79, 166, 97)]
# Initial detected boxes:  [(78.0, 147, 80, 166, 99)]
# Detected boxes:  147 80 166 99
# Initial ground_truth_boxes:  [(109, 78, 250, 185)]
# Initial detected boxes:  [(87.0, 116, 79, 250, 192)]
# Detected boxes:  116 79 250 192
# Initial ground_truth_boxes:  [(130, 106, 160, 141)]
# Initial detected boxes:  [(82.0, 129, 105, 162, 143)]
# Detected boxes:  129 105 162 143
# Initial ground_truth_boxes:  [(169, 157, 216, 207)]
# Initial detected boxes:  [(83.0, 170, 160, 216, 204)]
# Detected boxes:  170 160 216 204
# Initial ground_truth_boxes:  [(135, 112, 155, 130)]
# Initial detected boxes:  [(83.0, 135, 111, 154, 131)]
# Detected boxes:  135 111 154 131
# Initial ground_truth_boxes:  [(131, 86, 159, 106)]
# Initial detected boxes:  [(73.0, 121, 84, 161, 114)]
# Detected boxes:  121 84 161 114
# Initial ground_truth_boxes:  [(148, 120, 162, 133)]
# Initial detected boxes:  [(79.0, 144, 117, 163, 135)]
# Detected boxes:  144 117 163 135
# Initial ground_truth_boxes:  [(127, 106, 148, 125)]
# Initial detected boxes:  [(83.0, 126, 106, 146, 126)]
# Detected boxes:  126 106 146 126
# Initial ground_truth_boxes:  [(142, 95, 182, 138)]
# Initial detected boxes:  [(87.0, 141, 95, 180, 136)]
# Detected boxes:  141 95 180 136
# Initial ground_truth_boxes:  [(148, 114, 159, 127), (145, 231, 156, 244)]
# Initial detected boxes:  [(62.0, 144, 230, 156, 242)]
# Detected boxes:  144 230 156 242
# Initial ground_truth_boxes:  [(190, 111, 230, 148)]
# Initial detected boxes:  [(83.0, 189, 113, 236, 150)]
# Detected boxes:  189 113 236 150
# Initial ground_truth_boxes:  [(91, 85, 155, 151)]
# Initial detected boxes:  [(87.0, 91, 79, 159, 153)]
# Detected boxes:  91 79 159 153
# Initial ground_truth_boxes:  [(139, 156, 149, 167)]
# Initial detected boxes:  [(64.0, 139, 157, 148, 166)]
# Detected boxes:  139 157 148 166
# Initial ground_truth_boxes:  [(170, 102, 205, 146)]
# Initial detected boxes:  [(81.0, 166, 102, 203, 147)]
# Detected boxes:  166 102 203 147
# Initial ground_truth_boxes:  [(112, 146, 127, 160)]
# The file /content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/40_Zone_3_Mine_1cm_depth__11-m_TemperatureInCenter__31-C_jpg.rf.29ce5c6f99191002228775e19320df59.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(146, 109, 167, 127), (307, 144, 315, 154), (173, 242, 195, 256)]
# Initial detected boxes:  [(62.0, 307, 144, 315, 154)]
# Detected boxes:  307 144 315 154
# Initial ground_truth_boxes:  [(104, 1, 266, 121)]
# Initial detected boxes:  [(89.0, 109, 0, 262, 122)]
# Detected boxes:  109 0 262 122
# Initial ground_truth_boxes:  [(182, 39, 208, 59)]
# Initial detected boxes:  [(77.0, 182, 39, 208, 62)]
# Detected boxes:  182 39 208 62
# Initial ground_truth_boxes:  [(110, 75, 200, 146)]
# Initial detected boxes:  [(89.0, 113, 78, 199, 147)]
# Detected boxes:  113 78 199 147
# Initial ground_truth_boxes:  [(258, 97, 270, 113), (13, 104, 23, 115)]
# Initial detected boxes:  [(31.0, 257, 100, 269, 114)]
# Detected boxes:  257 100 269 114
# Initial ground_truth_boxes:  [(121, 134, 134, 152)]
# Initial detected boxes:  [(75.0, 120, 135, 134, 153)]
# Detected boxes:  120 135 134 153
# Initial ground_truth_boxes:  [(142, 99, 178, 138)]
# Initial detected boxes:  [(84.0, 136, 99, 177, 141)]
# Detected boxes:  136 99 177 141
# Initial ground_truth_boxes:  [(306, 87, 326, 106)]
# Initial detected boxes:  [(47.0, 308, 89, 324, 107)]
# Detected boxes:  308 89 324 107
# Initial ground_truth_boxes:  [(15, 45, 110, 152)]
# Initial detected boxes:  [(86.0, 17, 43, 111, 147)]
# Detected boxes:  17 43 111 147
# Initial ground_truth_boxes:  [(134, 134, 145, 148)]
# Initial detected boxes:  [(80.0, 134, 133, 146, 148)]
# Detected boxes:  134 133 146 148
# Initial ground_truth_boxes:  [(94, 92, 118, 115)]
# Initial detected boxes:  [(80.0, 96, 93, 116, 114)]
# Detected boxes:  96 93 116 114
# Initial ground_truth_boxes:  [(169, 82, 194, 110)]
# Initial detected boxes:  [(75.0, 170, 83, 197, 108)]
# Detected boxes:  170 83 197 108
# Initial ground_truth_boxes:  [(133, 110, 148, 127)]
# Initial detected boxes:  [(77.0, 133, 113, 145, 127)]
# Detected boxes:  133 113 145 127
# Initial ground_truth_boxes:  [(143, 109, 188, 143)]
# Initial detected boxes:  [(86.0, 142, 106, 186, 144)]
# Detected boxes:  142 106 186 144
# Initial ground_truth_boxes:  [(124, 97, 146, 116), (257, 126, 265, 136)]
# Initial detected boxes:  [(75.0, 127, 99, 147, 116)]
# Detected boxes:  127 99 147 116
# Initial ground_truth_boxes:  [(114, 83, 137, 105), (292, 121, 307, 136)]
# Initial detected boxes:  [(77.0, 294, 122, 306, 135)]
# Detected boxes:  294 122 306 135
# Initial ground_truth_boxes:  [(135, 82, 158, 101), (282, 108, 293, 117)]
# Initial detected boxes:  [(41.0, 281, 106, 292, 118)]
# Detected boxes:  281 106 292 118
# Initial ground_truth_boxes:  [(127, 130, 138, 141)]
# Initial detected boxes:  [(81.0, 127, 128, 138, 141)]
# Detected boxes:  127 128 138 141
# Initial ground_truth_boxes:  [(125, 104, 143, 120), (157, 231, 175, 248)]
# Initial detected boxes:  [(64.0, 120, 103, 147, 124)]
# Detected boxes:  120 103 147 124
# Initial ground_truth_boxes:  [(130, 97, 166, 134)]
# Initial detected boxes:  [(83.0, 128, 97, 168, 133)]
# Detected boxes:  128 97 168 133
# Initial ground_truth_boxes:  [(53, 114, 122, 179)]
# Initial detected boxes:  [(78.0, 60, 115, 111, 164)]
# Detected boxes:  60 115 111 164
# Initial ground_truth_boxes:  [(125, 112, 170, 155)]
# Initial detected boxes:  [(80.0, 124, 112, 170, 152)]
# Detected boxes:  124 112 170 152
# Initial ground_truth_boxes:  [(121, 107, 134, 119), (111, 207, 124, 224), (135, 4, 148, 19)]
# Initial detected boxes:  [(48.0, 135, 5, 149, 19)]
# Detected boxes:  135 5 149 19
# Initial ground_truth_boxes:  [(152, 98, 172, 118)]
# Initial detected boxes:  [(75.0, 150, 100, 171, 119)]
# Detected boxes:  150 100 171 119
# Initial ground_truth_boxes:  [(230, 180, 247, 196)]
# Initial detected boxes:  [(63.0, 0, 107, 11, 120)]
# Detected boxes:  0 107 11 120
# Initial ground_truth_boxes:  [(46, 56, 231, 217)]
# Initial detected boxes:  [(86.0, 53, 54, 234, 217)]
# Detected boxes:  53 54 234 217
# Initial ground_truth_boxes:  [(210, 166, 221, 177)]
# Initial detected boxes:  [(82.0, 210, 166, 221, 178)]
# Detected boxes:  210 166 221 178
# Initial ground_truth_boxes:  [(165, 110, 188, 134)]
# Initial detected boxes:  [(80.0, 165, 112, 187, 135)]
# Detected boxes:  165 112 187 135
# Initial ground_truth_boxes:  [(109, 112, 127, 131)]
# Initial detected boxes:  [(78.0, 110, 113, 127, 131)]
# Detected boxes:  110 113 127 131
# Initial ground_truth_boxes:  []
# The file /content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/491_Zone_6__free_zone__0-8m_TemperatureInCenter__27-C_jpg.rf.f6a4b730676f4fcf3327d3974fea3b28.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(140, 110, 162, 125)]
# Initial detected boxes:  [(76.0, 139, 109, 161, 129)]
# Detected boxes:  139 109 161 129
# Initial ground_truth_boxes:  [(117, 44, 280, 256)]
# Initial detected boxes:  [(88.0, 120, 52, 269, 242)]
# Detected boxes:  120 52 269 242
# Initial ground_truth_boxes:  [(114, 165, 144, 195)]
# Initial detected boxes:  [(85.0, 111, 160, 148, 194)]
# Detected boxes:  111 160 148 194
# Initial ground_truth_boxes:  [(175, 158, 183, 168), (13, 131, 29, 144)]
# Initial detected boxes:  [(72.0, 11, 128, 31, 146)]
# Detected boxes:  11 128 31 146
# Initial ground_truth_boxes:  [(114, 140, 127, 152)]
# Initial detected boxes:  [(59.0, 114, 141, 126, 153)]
# Detected boxes:  114 141 126 153
# Initial ground_truth_boxes:  [(149, 123, 168, 141)]
# Initial detected boxes:  [(77.0, 151, 124, 166, 142)]
# Detected boxes:  151 124 166 142
# Initial ground_truth_boxes:  [(128, 121, 159, 147)]
# Initial detected boxes:  [(78.0, 127, 121, 160, 148)]
# Detected boxes:  127 121 160 148
# Initial ground_truth_boxes:  [(128, 102, 167, 141)]
# Initial detected boxes:  [(81.0, 126, 103, 164, 140)]
# Detected boxes:  126 103 164 140
# Initial ground_truth_boxes:  [(165, 116, 186, 141)]
# Initial detected boxes:  [(82.0, 163, 117, 187, 140)]
# Detected boxes:  163 117 187 140
# Initial ground_truth_boxes:  [(146, 128, 171, 151)]
# Initial detected boxes:  [(83.0, 147, 128, 170, 151)]
# Detected boxes:  147 128 170 151
# Initial ground_truth_boxes:  []
# The file /content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/213_Zone_6__free_zone__7-3m_TemperatureInCenter__29-C_jpg.rf.f69a741d1242eb458c6852108149f58d.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(110, 30, 226, 172)]
# Initial detected boxes:  [(88.0, 109, 29, 215, 173)]
# Detected boxes:  109 29 215 173
# Initial ground_truth_boxes:  [(140, 94, 160, 112)]
# Initial detected boxes:  [(77.0, 142, 97, 160, 113)]
# Detected boxes:  142 97 160 113
# Initial ground_truth_boxes:  [(82, 32, 209, 130)]
# Initial detected boxes:  [(85.0, 84, 41, 210, 134)]
# Detected boxes:  84 41 210 134
# Initial ground_truth_boxes:  [(116, 114, 129, 129)]
# Initial detected boxes:  [(74.0, 115, 114, 128, 128)]
# Detected boxes:  115 114 128 128
# Initial ground_truth_boxes:  [(101, 91, 143, 121)]
# Initial detected boxes:  [(84.0, 102, 91, 142, 123)]
# Detected boxes:  102 91 142 123
# Initial ground_truth_boxes:  [(140, 130, 153, 144)]
# Initial detected boxes:  [(72.0, 138, 129, 153, 143)]
# Detected boxes:  138 129 153 143
# Initial ground_truth_boxes:  [(134, 120, 172, 144)]
# Initial detected boxes:  [(75.0, 134, 115, 180, 152)]
# Detected boxes:  134 115 180 152
# Initial ground_truth_boxes:  [(104, 10, 292, 229)]
# Initial detected boxes:  [(93.0, 116, 10, 281, 220)]
# Detected boxes:  116 10 281 220
# Initial ground_truth_boxes:  [(165, 136, 182, 155)]
# Initial detected boxes:  [(82.0, 164, 138, 183, 156)]
# Detected boxes:  164 138 183 156
# Initial ground_truth_boxes:  [(117, 116, 125, 125)]
# Initial detected boxes:  [(61.0, 116, 117, 124, 125)]
# Detected boxes:  116 117 124 125
# Initial ground_truth_boxes:  [(146, 113, 157, 126)]
# Initial detected boxes:  [(76.0, 145, 112, 158, 126)]
# Detected boxes:  145 112 158 126
# Initial ground_truth_boxes:  []
# The file /content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/497_Zone_6__free_zone__4-7m_TemperatureInCenter__26-C_jpg.rf.794dad35967669e1f9fc29e5fee7f03c.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(68, 100, 199, 183)]
# Initial detected boxes:  [(84.0, 61, 59, 203, 186)]
# Detected boxes:  61 59 203 186
# Initial ground_truth_boxes:  [(147, 105, 162, 121)]
# Initial detected boxes:  [(81.0, 147, 106, 163, 122)]
# Detected boxes:  147 106 163 122
# Initial ground_truth_boxes:  [(122, 155, 156, 186)]
# Initial detected boxes:  [(88.0, 121, 156, 156, 188)]
# Detected boxes:  121 156 156 188
# Initial ground_truth_boxes:  [(132, 84, 156, 113)]
# Initial detected boxes:  [(84.0, 130, 82, 155, 112)]
# Detected boxes:  130 82 155 112
# Initial ground_truth_boxes:  [(146, 116, 176, 147)]
# Initial detected boxes:  [(86.0, 144, 116, 175, 147)]
# Detected boxes:  144 116 175 147
# Initial ground_truth_boxes:  [(107, 12, 265, 191)]
# Initial detected boxes:  [(86.0, 113, 2, 262, 196)]
# Detected boxes:  113 2 262 196
# Initial ground_truth_boxes:  [(118, 120, 154, 148)]
# Initial detected boxes:  [(75.0, 122, 114, 160, 149)]
# Detected boxes:  122 114 160 149
# Initial ground_truth_boxes:  [(130, 64, 150, 83)]
# Initial detected boxes:  [(73.0, 130, 64, 150, 83)]
# Detected boxes:  130 64 150 83
# Initial ground_truth_boxes:  [(119, 102, 149, 123)]
# Initial detected boxes:  [(75.0, 119, 101, 148, 125)]
# Detected boxes:  119 101 148 125
# Initial ground_truth_boxes:  [(64, 87, 173, 178)]
# Initial detected boxes:  [(89.0, 67, 84, 170, 178)]
# Detected boxes:  67 84 170 178
# Initial ground_truth_boxes:  [(134, 164, 144, 176)]
# Initial detected boxes:  [(76.0, 133, 165, 144, 176)]
# Detected boxes:  133 165 144 176
# Initial ground_truth_boxes:  [(123, 92, 141, 114)]
# Initial detected boxes:  [(83.0, 123, 93, 141, 114)]
# Detected boxes:  123 93 141 114
# Initial ground_truth_boxes:  [(140, 122, 151, 132)]
# Initial detected boxes:  [(72.0, 139, 121, 151, 133)]
# Detected boxes:  139 121 151 133
# Initial ground_truth_boxes:  [(178, 109, 228, 153)]
# The file /content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/648_Zone_9_Mine_10_cm_depth__-0-m_TemperatureInCenter__30-C_jpg.rf.a2f45670764ece262a4e54c67e83766f.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(142, 109, 222, 182)]
# Initial detected boxes:  [(86.0, 141, 111, 223, 180)]
# Detected boxes:  141 111 223 180
# Initial ground_truth_boxes:  [(124, 94, 138, 112)]
# Initial detected boxes:  [(82.0, 124, 96, 138, 113)]
# Detected boxes:  124 96 138 113
# Images without detected objects:  ['/content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/355_Zone_6__free_zone__4-0m_TemperatureInCenter__32-C_jpg.rf.5c243c643decb8828712740624fce6b4.txt', '/content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/75_Zone_6__free_zone__1-7m_TemperatureInCenter__30-C_jpg.rf.10b33677800c257b702e5a2b4c294e20.txt', '/content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/208_Zone_6__free_zone__2-4m_TemperatureInCenter__30-C_jpg.rf.107304a301815c828391449a671ddba5.txt', '/content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/40_Zone_3_Mine_1cm_depth__11-m_TemperatureInCenter__31-C_jpg.rf.29ce5c6f99191002228775e19320df59.txt', '/content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/491_Zone_6__free_zone__0-8m_TemperatureInCenter__27-C_jpg.rf.f6a4b730676f4fcf3327d3974fea3b28.txt', '/content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/213_Zone_6__free_zone__7-3m_TemperatureInCenter__29-C_jpg.rf.f69a741d1242eb458c6852108149f58d.txt', '/content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/497_Zone_6__free_zone__4-7m_TemperatureInCenter__26-C_jpg.rf.794dad35967669e1f9fc29e5fee7f03c.txt', '/content/drive/MyDrive/University/Research_Module/development/Landmine detection/results_txt/detection_results_custom_YOLO/648_Zone_9_Mine_10_cm_depth__-0-m_TemperatureInCenter__30-C_jpg.rf.a2f45670764ece262a4e54c67e83766f.txt']

# %%
# SSD run
# Folder paths
import os
output_folder = "/content/result_boundingbox_images_SSD"
# Create the directory if it doesn't exist
os.makedirs(output_folder, exist_ok=True)


image_folder = "/content/drive/MyDrive/University/Research_Module/dataset/Yolov8_v3_dataset/Landmines detection dataset.v3i.yolov8/test/images"
ground_truth_folder = "/content/drive/MyDrive/University/Research_Module/dataset/Yolov8_v3_dataset/Landmines detection dataset.v3i.yolov8/test/labels"  # Change to your ground truth folder path
detected_folder = "/content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt"

images_with_no_detection=[]

# Iterate over images in the image folder
for image_name in os.listdir(image_folder):
    image_path = os.path.join(image_folder, image_name)

    # Load ground truth and detected boxes
    ground_truth_path = os.path.join(ground_truth_folder, os.path.splitext(image_name)[0] + ".txt")
    detected_path = os.path.join(detected_folder, os.path.splitext(image_name)[0] + ".txt")

    ground_truth_boxes = load_boxes_from_txt(ground_truth_path, True)
    print("Initial ground_truth_boxes: ",ground_truth_boxes);
    detected_boxes = load_boxes_from_txt(detected_path, False, images_with_no_detection, True)
    print("Initial detected boxes: ",detected_boxes);

    # Draw and save the image with bounding boxes
    output_path = os.path.join(output_folder, os.path.splitext(image_name)[0] + "_result.jpg")
    draw_boxes(image_path, ground_truth_boxes, detected_boxes, output_path)
print("Images without detected objects: ", images_with_no_detection) #they do not include the cases when there are multiple objects and 1 was missed
# Out:
# Initial ground_truth_boxes:  [(81, 76, 155, 134)]
# Initial detected boxes:  [(82.0, 82, 78, 149, 130)]
# Detected boxes:  82 78 149 130
# Initial ground_truth_boxes:  [(115, 71, 155, 102)]
# Initial detected boxes:  [(112.0, 112, 73, 151, 102)]
# Detected boxes:  112 73 151 102
# Initial ground_truth_boxes:  [(105, 85, 198, 154)]
# Initial detected boxes:  [(107.0, 107, 76, 198, 154)]
# Detected boxes:  107 76 198 154
# Initial ground_truth_boxes:  [(137, 100, 178, 139)]
# The file /content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/91_Zone_7_Mine_5cm_depth__2-0m_TemperatureInCenter__32-C_jpg.rf.3b6a046ca434cbf82f1bc0d13b9b93ac.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(113, 111, 137, 131)]
# Initial detected boxes:  [(187.0, 187, 49, 200, 60)]
# Detected boxes:  187 49 200 60
# Initial ground_truth_boxes:  [(115, 126, 146, 150)]
# Initial detected boxes:  [(115.0, 115, 122, 148, 150)]
# Detected boxes:  115 122 148 150
# Initial ground_truth_boxes:  [(113, 137, 143, 165)]
# Initial detected boxes:  [(113.0, 113, 134, 145, 166)]
# Detected boxes:  113 134 145 166
# Initial ground_truth_boxes:  [(105, 91, 199, 166)]
# Initial detected boxes:  [(107.0, 107, 88, 197, 167)]
# Detected boxes:  107 88 197 167
# Initial ground_truth_boxes:  [(151, 130, 172, 153)]
# Initial detected boxes:  [(151.0, 151, 129, 174, 153)]
# Detected boxes:  151 129 174 153
# Initial ground_truth_boxes:  [(129, 147, 143, 160), (135, 0, 154, 13)]
# Initial detected boxes:  [(113.0, 113, 180, 129, 196)]
# Detected boxes:  113 180 129 196
# Initial ground_truth_boxes:  [(112, 122, 124, 137)]
# Initial detected boxes:  [(109.0, 109, 250, 124, 256)]
# Detected boxes:  109 250 124 256
# Initial ground_truth_boxes:  [(136, 55, 273, 167)]
# Initial detected boxes:  [(137.0, 137, 54, 271, 167)]
# Detected boxes:  137 54 271 167
# Initial ground_truth_boxes:  [(144, 116, 172, 140)]
# Initial detected boxes:  [(145.0, 145, 111, 170, 135)]
# Detected boxes:  145 111 170 135
# Initial ground_truth_boxes:  [(285, 103, 300, 122)]
# Initial detected boxes:  [(285.0, 285, 103, 297, 121)]
# Detected boxes:  285 103 297 121
# Initial ground_truth_boxes:  [(134, 106, 202, 186)]
# Initial detected boxes:  [(133.0, 133, 107, 197, 183)]
# Detected boxes:  133 107 197 183
# Initial ground_truth_boxes:  [(108, 115, 182, 176)]
# Initial detected boxes:  [(295.0, 295, 111, 313, 132)]
# Detected boxes:  295 111 313 132
# Initial ground_truth_boxes:  [(125, 92, 149, 115), (275, 127, 287, 140)]
# Initial detected boxes:  [(276.0, 276, 129, 286, 139)]
# Detected boxes:  276 129 286 139
# Initial ground_truth_boxes:  []
# The file /content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/355_Zone_6__free_zone__4-0m_TemperatureInCenter__32-C_jpg.rf.5c243c643decb8828712740624fce6b4.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(135, 30, 234, 168)]
# Initial detected boxes:  [(134.0, 134, 26, 234, 170)]
# Detected boxes:  134 26 234 170
# Initial ground_truth_boxes:  [(146, 126, 164, 141)]
# Initial detected boxes:  [(151.0, 151, 126, 167, 138)]
# Detected boxes:  151 126 167 138
# Initial ground_truth_boxes:  [(113, 131, 144, 162)]
# The file /content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/92_Zone_7_Mine_5cm_depth__2-1m_TemperatureInCenter__31-C_jpg.rf.3695957994bf5e0473bc6fe88d08d274.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(103, 95, 198, 170)]
# Initial detected boxes:  [(110.0, 110, 98, 194, 171)]
# Detected boxes:  110 98 194 171
# Initial ground_truth_boxes:  [(128, 83, 171, 110)]
# Initial detected boxes:  [(127.0, 127, 83, 171, 112)]
# Detected boxes:  127 83 171 112
# Initial ground_truth_boxes:  [(66, 0, 241, 136)]
# Initial detected boxes:  [(63.0, 63, 1, 248, 136)]
# Detected boxes:  63 1 248 136
# Initial ground_truth_boxes:  [(128, 30, 190, 108)]
# Initial detected boxes:  [(123.0, 123, 34, 198, 108)]
# Detected boxes:  123 34 198 108
# Initial ground_truth_boxes:  [(208, 80, 230, 99)]
# Initial detected boxes:  [(209.0, 209, 78, 233, 99)]
# Detected boxes:  209 78 233 99
# Initial ground_truth_boxes:  []
# The file /content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/75_Zone_6__free_zone__1-7m_TemperatureInCenter__30-C_jpg.rf.10b33677800c257b702e5a2b4c294e20.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(115, 137, 129, 150)]
# Initial detected boxes:  [(116.0, 116, 138, 133, 150)]
# Detected boxes:  116 138 133 150
# Initial ground_truth_boxes:  [(135, 91, 157, 114)]
# Initial detected boxes:  [(131.0, 131, 122, 179, 155)]
# Detected boxes:  131 122 179 155
# Initial ground_truth_boxes:  [(119, 21, 201, 89)]
# Initial detected boxes:  [(191.0, 191, 105, 219, 122)]
# Detected boxes:  191 105 219 122
# Initial ground_truth_boxes:  [(140, 137, 162, 156)]
# Initial detected boxes:  [(138.0, 138, 135, 163, 155)]
# Detected boxes:  138 135 163 155
# Initial ground_truth_boxes:  [(181, 129, 201, 147)]
# Initial detected boxes:  [(181.0, 181, 131, 198, 146)]
# Detected boxes:  181 131 198 146
# Initial ground_truth_boxes:  [(86, 1, 279, 199)]
# Initial detected boxes:  [(92.0, 92, 1, 271, 205)]
# Detected boxes:  92 1 271 205
# Initial ground_truth_boxes:  [(146, 104, 158, 116)]
# Initial detected boxes:  [(144.0, 144, 103, 157, 117)]
# Detected boxes:  144 103 157 117
# Initial ground_truth_boxes:  [(126, 96, 140, 110)]
# Initial detected boxes:  [(123.0, 123, 95, 142, 112)]
# Detected boxes:  123 95 142 112
# Initial ground_truth_boxes:  [(122, 65, 161, 100)]
# Initial detected boxes:  [(122.0, 122, 62, 159, 102)]
# Detected boxes:  122 62 159 102
# Initial ground_truth_boxes:  [(156, 151, 169, 163)]
# Initial detected boxes:  [(157.0, 157, 150, 172, 162)]
# Detected boxes:  157 150 172 162
# Initial ground_truth_boxes:  [(105, 130, 133, 157)]
# Initial detected boxes:  [(103.0, 103, 127, 136, 158)]
# Detected boxes:  103 127 136 158
# Initial ground_truth_boxes:  [(141, 106, 174, 138)]
# Initial detected boxes:  [(139.0, 139, 106, 174, 139)]
# Detected boxes:  139 106 174 139
# Initial ground_truth_boxes:  [(108, 109, 122, 122)]
# Initial detected boxes:  [(173.0, 173, 9, 189, 22)]
# Detected boxes:  173 9 189 22
# Initial ground_truth_boxes:  [(167, 38, 255, 167)]
# Initial detected boxes:  [(164.0, 164, 36, 260, 165)]
# Detected boxes:  164 36 260 165
# Initial ground_truth_boxes:  []
# The file /content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/208_Zone_6__free_zone__2-4m_TemperatureInCenter__30-C_jpg.rf.107304a301815c828391449a671ddba5.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(132, 134, 161, 157)]
# Initial detected boxes:  [(133.0, 133, 134, 161, 156)]
# Detected boxes:  133 134 161 156
# Initial ground_truth_boxes:  [(99, 144, 124, 169)]
# Initial detected boxes:  [(99.0, 99, 142, 122, 167)]
# Detected boxes:  99 142 122 167
# Initial ground_truth_boxes:  [(147, 79, 166, 97)]
# Initial detected boxes:  [(147.0, 147, 80, 167, 98)]
# Detected boxes:  147 80 167 98
# Initial ground_truth_boxes:  [(109, 78, 250, 185)]
# Initial detected boxes:  [(77.0, 77, 39, 107, 64)]
# Detected boxes:  77 39 107 64
# Initial ground_truth_boxes:  [(130, 106, 160, 141)]
# Initial detected boxes:  [(130.0, 130, 108, 161, 142)]
# Detected boxes:  130 108 161 142
# Initial ground_truth_boxes:  [(169, 157, 216, 207)]
# Initial detected boxes:  [(173.0, 173, 161, 214, 201)]
# Detected boxes:  173 161 214 201
# Initial ground_truth_boxes:  [(135, 112, 155, 130)]
# Initial detected boxes:  [(45.0, 45, 1, 60, 10)]
# Detected boxes:  45 1 60 10
# Initial ground_truth_boxes:  [(131, 86, 159, 106)]
# Initial detected boxes:  [(124.0, 124, 86, 157, 109)]
# Detected boxes:  124 86 157 109
# Initial ground_truth_boxes:  [(148, 120, 162, 133)]
# Initial detected boxes:  [(144.0, 144, 116, 162, 134)]
# Detected boxes:  144 116 162 134
# Initial ground_truth_boxes:  [(127, 106, 148, 125)]
# Initial detected boxes:  [(278.0, 278, 210, 291, 222)]
# Detected boxes:  278 210 291 222
# Initial ground_truth_boxes:  [(142, 95, 182, 138)]
# Initial detected boxes:  [(141.0, 141, 96, 180, 135)]
# Detected boxes:  141 96 180 135
# Initial ground_truth_boxes:  [(148, 114, 159, 127), (145, 231, 156, 244)]
# Initial detected boxes:  [(146.0, 146, 235, 157, 244)]
# Detected boxes:  146 235 157 244
# Initial ground_truth_boxes:  [(190, 111, 230, 148)]
# Initial detected boxes:  [(190.0, 190, 115, 232, 148)]
# Detected boxes:  190 115 232 148
# Initial ground_truth_boxes:  [(91, 85, 155, 151)]
# Initial detected boxes:  [(89.0, 89, 84, 166, 155)]
# Detected boxes:  89 84 166 155
# Initial ground_truth_boxes:  [(139, 156, 149, 167)]
# Initial detected boxes:  [(1.0, 1, 124, 6, 134)]
# Detected boxes:  1 124 6 134
# Initial ground_truth_boxes:  [(170, 102, 205, 146)]
# Initial detected boxes:  [(167.0, 167, 104, 203, 145)]
# Detected boxes:  167 104 203 145
# Initial ground_truth_boxes:  [(112, 146, 127, 160)]
# Initial detected boxes:  [(109.0, 109, 148, 125, 161)]
# Detected boxes:  109 148 125 161
# Initial ground_truth_boxes:  [(146, 109, 167, 127), (307, 144, 315, 154), (173, 242, 195, 256)]
# Initial detected boxes:  [(172.0, 172, 241, 192, 256)]
# Detected boxes:  172 241 192 256
# Initial ground_truth_boxes:  [(104, 1, 266, 121)]
# Initial detected boxes:  [(110.0, 110, 1, 259, 123)]
# Detected boxes:  110 1 259 123
# Initial ground_truth_boxes:  [(182, 39, 208, 59)]
# Initial detected boxes:  [(182.0, 182, 38, 209, 60)]
# Detected boxes:  182 38 209 60
# Initial ground_truth_boxes:  [(110, 75, 200, 146)]
# Initial detected boxes:  [(101.0, 101, 52, 132, 71)]
# Detected boxes:  101 52 132 71
# Initial ground_truth_boxes:  [(258, 97, 270, 113), (13, 104, 23, 115)]
# Initial detected boxes:  [(10.0, 10, 103, 23, 114)]
# Detected boxes:  10 103 23 114
# Initial ground_truth_boxes:  [(121, 134, 134, 152)]
# Initial detected boxes:  [(117.0, 117, 135, 134, 154)]
# Detected boxes:  117 135 134 154
# Initial ground_truth_boxes:  [(142, 99, 178, 138)]
# Initial detected boxes:  [(138.0, 138, 99, 176, 138)]
# Detected boxes:  138 99 176 138
# Initial ground_truth_boxes:  [(306, 87, 326, 106)]
# Initial detected boxes:  [(306.0, 306, 87, 326, 107)]
# Detected boxes:  306 87 326 107
# Initial ground_truth_boxes:  [(15, 45, 110, 152)]
# Initial detected boxes:  [(15.0, 15, 41, 111, 150)]
# Detected boxes:  15 41 111 150
# Initial ground_truth_boxes:  [(134, 134, 145, 148)]
# Initial detected boxes:  [(133.0, 133, 133, 145, 146)]
# Detected boxes:  133 133 145 146
# Initial ground_truth_boxes:  [(94, 92, 118, 115)]
# Initial detected boxes:  [(95.0, 95, 92, 115, 113)]
# Detected boxes:  95 92 115 113
# Initial ground_truth_boxes:  [(169, 82, 194, 110)]
# Initial detected boxes:  [(169.0, 169, 83, 199, 111)]
# Detected boxes:  169 83 199 111
# Initial ground_truth_boxes:  [(133, 110, 148, 127)]
# Initial detected boxes:  [(128.0, 128, 111, 143, 125)]
# Detected boxes:  128 111 143 125
# Initial ground_truth_boxes:  [(143, 109, 188, 143)]
# Initial detected boxes:  [(142.0, 142, 105, 186, 143)]
# Detected boxes:  142 105 186 143
# Initial ground_truth_boxes:  [(124, 97, 146, 116), (257, 126, 265, 136)]
# Initial detected boxes:  [(260.0, 260, 125, 269, 135)]
# Detected boxes:  260 125 269 135
# Initial ground_truth_boxes:  [(114, 83, 137, 105), (292, 121, 307, 136)]
# Initial detected boxes:  [(289.0, 289, 123, 304, 135)]
# Detected boxes:  289 123 304 135
# Initial ground_truth_boxes:  [(135, 82, 158, 101), (282, 108, 293, 117)]
# Initial detected boxes:  [(282.0, 282, 107, 291, 117)]
# Detected boxes:  282 107 291 117
# Initial ground_truth_boxes:  [(127, 130, 138, 141)]
# Initial detected boxes:  [(124.0, 124, 236, 134, 248)]
# Detected boxes:  124 236 134 248
# Initial ground_truth_boxes:  [(125, 104, 143, 120), (157, 231, 175, 248)]
# Initial detected boxes:  [(154.0, 154, 230, 176, 248)]
# Detected boxes:  154 230 176 248
# Initial ground_truth_boxes:  [(130, 97, 166, 134)]
# Initial detected boxes:  [(126.0, 126, 100, 166, 134)]
# Detected boxes:  126 100 166 134
# Initial ground_truth_boxes:  [(53, 114, 122, 179)]
# The file /content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/94_Zone_7_Mine_5cm_depth__2-3m_TemperatureInCenter__28-C_jpg.rf.7e129ccba5cb7c9c7d934da9e1b5e64b.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(125, 112, 170, 155)]
# Initial detected boxes:  [(124.0, 124, 112, 167, 150)]
# Detected boxes:  124 112 167 150
# Initial ground_truth_boxes:  [(121, 107, 134, 119), (111, 207, 124, 224), (135, 4, 148, 19)]
# Initial detected boxes:  [(255.0, 255, 236, 277, 255)]
# Detected boxes:  255 236 277 255
# Initial ground_truth_boxes:  [(152, 98, 172, 118)]
# Initial detected boxes:  [(137.0, 137, 1, 150, 6)]
# Detected boxes:  137 1 150 6
# Initial ground_truth_boxes:  [(230, 180, 247, 196)]
# Initial detected boxes:  [(1.0, 1, 106, 6, 119)]
# Detected boxes:  1 106 6 119
# Initial ground_truth_boxes:  [(46, 56, 231, 217)]
# Initial detected boxes:  [(51.0, 51, 59, 225, 214)]
# Detected boxes:  51 59 225 214
# Initial ground_truth_boxes:  [(210, 166, 221, 177)]
# Initial detected boxes:  [(209.0, 209, 166, 220, 177)]
# Detected boxes:  209 166 220 177
# Initial ground_truth_boxes:  [(165, 110, 188, 134)]
# Initial detected boxes:  [(164.0, 164, 112, 186, 134)]
# Detected boxes:  164 112 186 134
# Initial ground_truth_boxes:  [(109, 112, 127, 131)]
# Initial detected boxes:  [(107.0, 107, 111, 127, 130)]
# Detected boxes:  107 111 127 130
# Initial ground_truth_boxes:  []
# The file /content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/491_Zone_6__free_zone__0-8m_TemperatureInCenter__27-C_jpg.rf.f6a4b730676f4fcf3327d3974fea3b28.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(140, 110, 162, 125)]
# Initial detected boxes:  [(138.0, 138, 109, 159, 128)]
# Detected boxes:  138 109 159 128
# Initial ground_truth_boxes:  [(117, 44, 280, 256)]
# Initial detected boxes:  [(116.0, 116, 60, 270, 237)]
# Detected boxes:  116 60 270 237
# Initial ground_truth_boxes:  [(114, 165, 144, 195)]
# Initial detected boxes:  [(111.0, 111, 163, 148, 197)]
# Detected boxes:  111 163 148 197
# Initial ground_truth_boxes:  [(175, 158, 183, 168), (13, 131, 29, 144)]
# Initial detected boxes:  [(271.0, 271, 1, 283, 7)]
# Detected boxes:  271 1 283 7
# Initial ground_truth_boxes:  [(114, 140, 127, 152)]
# Initial detected boxes:  [(3.0, 3, 101, 9, 111)]
# Detected boxes:  3 101 9 111
# Initial ground_truth_boxes:  [(149, 123, 168, 141)]
# Initial detected boxes:  [(332.0, 332, 125, 334, 138)]
# Detected boxes:  332 125 334 138
# Initial ground_truth_boxes:  [(128, 121, 159, 147)]
# Initial detected boxes:  [(129.0, 129, 120, 160, 146)]
# Detected boxes:  129 120 160 146
# Initial ground_truth_boxes:  [(128, 102, 167, 141)]
# Initial detected boxes:  [(231.0, 231, 247, 244, 255)]
# Detected boxes:  231 247 244 255
# Initial ground_truth_boxes:  [(165, 116, 186, 141)]
# Initial detected boxes:  [(162.0, 162, 117, 188, 141)]
# Detected boxes:  162 117 188 141
# Initial ground_truth_boxes:  [(146, 128, 171, 151)]
# Initial detected boxes:  [(148.0, 148, 125, 172, 152)]
# Detected boxes:  148 125 172 152
# Initial ground_truth_boxes:  []
# Initial detected boxes:  [(334.0, 334, 80, 336, 94)]
# Detected boxes:  334 80 336 94
# Initial ground_truth_boxes:  [(110, 30, 226, 172)]
# Initial detected boxes:  [(110.0, 110, 27, 216, 173)]
# Detected boxes:  110 27 216 173
# Initial ground_truth_boxes:  [(140, 94, 160, 112)]
# Initial detected boxes:  [(264.0, 264, 15, 272, 27)]
# Detected boxes:  264 15 272 27
# Initial ground_truth_boxes:  [(82, 32, 209, 130)]
# Initial detected boxes:  [(85.0, 85, 25, 208, 135)]
# Detected boxes:  85 25 208 135
# Initial ground_truth_boxes:  [(116, 114, 129, 129)]
# Initial detected boxes:  [(114.0, 114, 113, 129, 128)]
# Detected boxes:  114 113 129 128
# Initial ground_truth_boxes:  [(101, 91, 143, 121)]
# Initial detected boxes:  [(101.0, 101, 92, 140, 121)]
# Detected boxes:  101 92 140 121
# Initial ground_truth_boxes:  [(140, 130, 153, 144)]
# Initial detected boxes:  [(139.0, 139, 128, 153, 142)]
# Detected boxes:  139 128 153 142
# Initial ground_truth_boxes:  [(134, 120, 172, 144)]
# Initial detected boxes:  [(135.0, 135, 117, 177, 146)]
# Detected boxes:  135 117 177 146
# Initial ground_truth_boxes:  [(104, 10, 292, 229)]
# Initial detected boxes:  [(111.0, 111, 1, 288, 225)]
# Detected boxes:  111 1 288 225
# Initial ground_truth_boxes:  [(165, 136, 182, 155)]
# Initial detected boxes:  [(163.0, 163, 138, 183, 155)]
# Detected boxes:  163 138 183 155
# Initial ground_truth_boxes:  [(117, 116, 125, 125)]
# Initial detected boxes:  [(122.0, 122, 111, 130, 120)]
# Detected boxes:  122 111 130 120
# Initial ground_truth_boxes:  [(146, 113, 157, 126)]
# Initial detected boxes:  [(145.0, 145, 113, 160, 128)]
# Detected boxes:  145 113 160 128
# Initial ground_truth_boxes:  []
# Initial detected boxes:  [(330.0, 330, 81, 333, 100)]
# Detected boxes:  330 81 333 100
# Initial ground_truth_boxes:  [(68, 100, 199, 183)]
# Initial detected boxes:  [(49.0, 49, 69, 203, 176)]
# Detected boxes:  49 69 203 176
# Initial ground_truth_boxes:  [(147, 105, 162, 121)]
# Initial detected boxes:  [(147.0, 147, 106, 162, 122)]
# Detected boxes:  147 106 162 122
# Initial ground_truth_boxes:  [(122, 155, 156, 186)]
# Initial detected boxes:  [(123.0, 123, 154, 157, 187)]
# Detected boxes:  123 154 157 187
# Initial ground_truth_boxes:  [(132, 84, 156, 113)]
# Initial detected boxes:  [(131.0, 131, 83, 153, 111)]
# Detected boxes:  131 83 153 111
# Initial ground_truth_boxes:  [(146, 116, 176, 147)]
# Initial detected boxes:  [(145.0, 145, 115, 176, 146)]
# Detected boxes:  145 115 176 146
# Initial ground_truth_boxes:  [(107, 12, 265, 191)]
# Initial detected boxes:  [(104.0, 104, 1, 264, 198)]
# Detected boxes:  104 1 264 198
# Initial ground_truth_boxes:  [(118, 120, 154, 148)]
# Initial detected boxes:  [(121.0, 121, 117, 158, 147)]
# Detected boxes:  121 117 158 147
# Initial ground_truth_boxes:  [(130, 64, 150, 83)]
# Initial detected boxes:  [(129.0, 129, 63, 149, 83)]
# Detected boxes:  129 63 149 83
# Initial ground_truth_boxes:  [(119, 102, 149, 123)]
# Initial detected boxes:  [(332.0, 332, 117, 334, 129)]
# Detected boxes:  332 117 334 129
# Initial ground_truth_boxes:  [(64, 87, 173, 178)]
# Initial detected boxes:  [(62.0, 62, 82, 170, 180)]
# Detected boxes:  62 82 170 180
# Initial ground_truth_boxes:  [(134, 164, 144, 176)]
# Initial detected boxes:  [(132.0, 132, 166, 144, 177)]
# Detected boxes:  132 166 144 177
# Initial ground_truth_boxes:  [(123, 92, 141, 114)]
# Initial detected boxes:  [(122.0, 122, 93, 139, 113)]
# Detected boxes:  122 93 139 113
# Initial ground_truth_boxes:  [(140, 122, 151, 132)]
# Initial detected boxes:  [(137.0, 137, 122, 150, 132)]
# Detected boxes:  137 122 150 132
# Initial ground_truth_boxes:  [(178, 109, 228, 153)]
# The file /content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/648_Zone_9_Mine_10_cm_depth__-0-m_TemperatureInCenter__30-C_jpg.rf.a2f45670764ece262a4e54c67e83766f.txt does not exist.
# Initial detected boxes:  []
# Initial ground_truth_boxes:  [(142, 109, 222, 182)]
# Initial detected boxes:  [(141.0, 141, 107, 222, 182)]
# Detected boxes:  141 107 222 182
# Initial ground_truth_boxes:  [(124, 94, 138, 112)]
# Initial detected boxes:  [(117.0, 117, 244, 141, 256)]
# Detected boxes:  117 244 141 256
# Images without detected objects:  ['/content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/91_Zone_7_Mine_5cm_depth__2-0m_TemperatureInCenter__32-C_jpg.rf.3b6a046ca434cbf82f1bc0d13b9b93ac.txt', '/content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/355_Zone_6__free_zone__4-0m_TemperatureInCenter__32-C_jpg.rf.5c243c643decb8828712740624fce6b4.txt', '/content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/92_Zone_7_Mine_5cm_depth__2-1m_TemperatureInCenter__31-C_jpg.rf.3695957994bf5e0473bc6fe88d08d274.txt', '/content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/75_Zone_6__free_zone__1-7m_TemperatureInCenter__30-C_jpg.rf.10b33677800c257b702e5a2b4c294e20.txt', '/content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/208_Zone_6__free_zone__2-4m_TemperatureInCenter__30-C_jpg.rf.107304a301815c828391449a671ddba5.txt', '/content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/94_Zone_7_Mine_5cm_depth__2-3m_TemperatureInCenter__28-C_jpg.rf.7e129ccba5cb7c9c7d934da9e1b5e64b.txt', '/content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/491_Zone_6__free_zone__0-8m_TemperatureInCenter__27-C_jpg.rf.f6a4b730676f4fcf3327d3974fea3b28.txt', '/content/drive/MyDrive/University/Research_Module/development/result_SSD_model/detection_result_txt/648_Zone_9_Mine_10_cm_depth__-0-m_TemperatureInCenter__30-C_jpg.rf.a2f45670764ece262a4e54c67e83766f.txt']

# %%
# Save images with bounding boxes
# ZIP folder with all the content
import shutil

# Create a zip file for default test validation results with curves pngs:
shutil.make_archive('/content/result_boundingbox_images_SSD', 'zip', '/content/result_boundingbox_images_SSD')
from google.colab import files
files.download('/content/result_boundingbox_images_SSD.zip')
